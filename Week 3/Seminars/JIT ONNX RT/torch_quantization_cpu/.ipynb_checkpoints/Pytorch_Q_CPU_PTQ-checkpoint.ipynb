# %% [markdown]
# ## PTQ - Post Training Quantization
#
# В этом туториале мы ускорим работу уже обученной модели ResNet18 на СPU с помощью инструментов Pytorch.
#
# - Сначало мы сделаем все необходимы импорты
# - Напишем все необходимые, вспомогательные функции
# - Импортируем датасеты
# - Инициализируем и загрузим нашу модель

# %%
import numpy as np
from time import time

import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import DataLoader

import torch.quantization
from torch.quantization import QuantStub, DeQuantStub
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/opt/conda/lib/python3.10/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# Функция для тестирования качества и калибровки модели

# %%
def test(model: nn.Module, dataloader: DataLoader, cuda=False) -> float:
    correct = 0
    total = 0
    model.eval()
    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data

            if cuda:
              inputs = inputs.cuda()
              labels = labels.cuda()

            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    
    print(f'Accuracy of the network on the test images: {100 * correct / total}%')
    return 100 * correct / total

# %% [markdown]
# Функция для замера времени вычислений

# %%
def test_time(model, n=100):

    time_total = np.zeros(shape=n)
    # run inference
    batch = torch.rand(1,3,32,32)
    for i in range(n):
        start = time()
        with torch.no_grad():
            output = model(batch)
        end = time()
        time_total[i] = end - start
        
    print(f'execution time for FP32 model is: {time_total.mean():.4f} +/- {time_total.std():.4f}')

# %% [markdown]
# Импорт датасетов

# %%
dataset = datasets.CIFAR10(
            root="./data",
            train=False,
            download=True,
            transform=transforms.Compose(
                [
                    transforms.ToTensor(),
                    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
                ]
            ),
        )
                               
testloader = torch.utils.data.DataLoader(dataset, batch_size=64,
                                         shuffle=False, num_workers=16, pin_memory=True)
# Out:
# Files already downloaded and verified

# %% [markdown]
# Создадим нашу модель с учетом квантования и загрузим веса

# %%
model_path = "./res18_acc_83.pth"
base = torchvision.models.resnet18()

base.fc = nn.Linear(base.fc.in_features, 10)

state_dict = torch.load(model_path, weights_only=True)
base.load_state_dict(state_dict)

class resnet(nn.Module):
    def __init__(self, base, q = False):
        # By turning on Q we can turn on/off the quantization
        super(resnet, self).__init__()
        self.q = q
        self.base = base
        if q:
          self.quant = QuantStub()
          self.dequant = DeQuantStub()

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        if self.q:
          x = self.quant(x)
          
        x = self.base(x)
        
        if self.q:
          x = self.dequant(x)
        return x


model = resnet(base, q=False)

# %%
score = test(model, testloader)
# Out:
# Accuracy of the network on the test images: 81.72%

# %%
model.eval()
model.to('cpu')
test_time(model)
# Out:
# execution time for FP32 model is: 0.0087 +/- 0.0014

# %% [markdown]
# ## PTQ
#
# Теперь мы квантуем нашу уже обученную модель, мы будем использовать MovingAverageMinMaxObserver для сбора статистик

# %%
from torch.ao.quantization import QConfigMapping
from torch.ao.quantization.quantize_fx import prepare_fx, convert_fx
from torch.quantization.observer import MovingAverageMinMaxObserver

qmodel = resnet(base, q=True)
qmodel.eval()


# Инициализируем конфиг квантования 
qconfig = torch.quantization.QConfig(activation=MovingAverageMinMaxObserver.with_args(reduce_range=True), 
                                      weight=MovingAverageMinMaxObserver.with_args(dtype=torch.qint8, qscheme=torch.per_tensor_symmetric))
qconfig_mapping = QConfigMapping().set_global(qconfig)

# Создадим модель для квантования и прокалибоуем ее на нашем датасете
prepared_model = prepare_fx(qmodel, qconfig_mapping, torch.randn(1,3,32,32))
score = test(prepared_model, testloader, cuda=False)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/ao/quantization/observer.py:221: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# Accuracy of the network on the test images: 81.72%

# %%
print(prepared_model)
# Out:
# GraphModule(
#   (activation_post_process_0): MovingAverageMinMaxObserver(min_val=-2.429065704345703, max_val=2.7537312507629395)
#   (base): Module(
#     (conv1): ConvReLU2d(
#       (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3))
#       (1): ReLU(inplace=True)
#     )
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (downsample): Module(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2))
#         )
#         (relu): ReLU(inplace=True)
#       )
#       (1): Module(
#         (conv1): ConvReLU2d(
#           (0): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=10, bias=True)
#   )
#   (activation_post_process_1): MovingAverageMinMaxObserver(min_val=0.0, max_val=4.09341287612915)
#   (activation_post_process_2): MovingAverageMinMaxObserver(min_val=0.0, max_val=4.09341287612915)
#   (activation_post_process_3): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.368614912033081)
#   (activation_post_process_4): MovingAverageMinMaxObserver(min_val=-3.6146297454833984, max_val=2.718867063522339)
#   (activation_post_process_5): MovingAverageMinMaxObserver(min_val=0.0, max_val=4.47843599319458)
#   (activation_post_process_6): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.2755541801452637)
#   (activation_post_process_7): MovingAverageMinMaxObserver(min_val=-5.409076690673828, max_val=3.3959808349609375)
#   (activation_post_process_8): MovingAverageMinMaxObserver(min_val=0.0, max_val=5.950730800628662)
#   (activation_post_process_9): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.0105671882629395)
#   (activation_post_process_10): MovingAverageMinMaxObserver(min_val=-2.9337663650512695, max_val=3.07448410987854)
#   (activation_post_process_11): MovingAverageMinMaxObserver(min_val=-3.2686550617218018, max_val=2.4001517295837402)
#   (activation_post_process_12): MovingAverageMinMaxObserver(min_val=0.0, max_val=3.593348741531372)
#   (activation_post_process_13): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.07029390335083)
#   (activation_post_process_14): MovingAverageMinMaxObserver(min_val=-3.40401029586792, max_val=2.171860456466675)
#   (activation_post_process_15): MovingAverageMinMaxObserver(min_val=0.0, max_val=4.441611289978027)
#   (activation_post_process_16): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.377976417541504)
#   (activation_post_process_17): MovingAverageMinMaxObserver(min_val=-2.2121331691741943, max_val=3.4858286380767822)
#   (activation_post_process_18): MovingAverageMinMaxObserver(min_val=-1.2955273389816284, max_val=1.615741491317749)
#   (activation_post_process_19): MovingAverageMinMaxObserver(min_val=0.0, max_val=3.839242696762085)
#   (activation_post_process_20): MovingAverageMinMaxObserver(min_val=0.0, max_val=2.3932557106018066)
#   (activation_post_process_21): MovingAverageMinMaxObserver(min_val=-4.9482102394104, max_val=2.3423664569854736)
#   (activation_post_process_22): MovingAverageMinMaxObserver(min_val=0.0, max_val=3.708381175994873)
#   (activation_post_process_23): MovingAverageMinMaxObserver(min_val=0.0, max_val=1.6409052610397339)
#   (activation_post_process_24): MovingAverageMinMaxObserver(min_val=-5.086153030395508, max_val=5.638824462890625)
#   (activation_post_process_25): MovingAverageMinMaxObserver(min_val=-1.7969090938568115, max_val=2.1822285652160645)
#   (activation_post_process_26): MovingAverageMinMaxObserver(min_val=0.0, max_val=5.498593330383301)
#   (activation_post_process_27): MovingAverageMinMaxObserver(min_val=0.0, max_val=5.965082168579102)
#   (activation_post_process_28): MovingAverageMinMaxObserver(min_val=-26.61410903930664, max_val=29.57421112060547)
#   (activation_post_process_29): MovingAverageMinMaxObserver(min_val=0.0, max_val=31.695499420166016)
#   (activation_post_process_30): MovingAverageMinMaxObserver(min_val=0.0, max_val=31.695499420166016)
#   (activation_post_process_31): MovingAverageMinMaxObserver(min_val=0.0, max_val=31.695499420166016)
#   (activation_post_process_32): MovingAverageMinMaxObserver(min_val=-112.71353912353516, max_val=11.809783935546875)
# )
#
#
#
# def forward(self, x : torch.Tensor) -> torch.Tensor:
#     activation_post_process_0 = self.activation_post_process_0(x);  x = None
#     base_conv1 = self.base.conv1(activation_post_process_0);  activation_post_process_0 = None
#     activation_post_process_1 = self.activation_post_process_1(base_conv1);  base_conv1 = None
#     base_maxpool = self.base.maxpool(activation_post_process_1);  activation_post_process_1 = None
#     activation_post_process_2 = self.activation_post_process_2(base_maxpool);  base_maxpool = None
#     base_layer1_0_conv1 = getattr(self.base.layer1, "0").conv1(activation_post_process_2)
#     activation_post_process_3 = self.activation_post_process_3(base_layer1_0_conv1);  base_layer1_0_conv1 = None
#     base_layer1_0_conv2 = getattr(self.base.layer1, "0").conv2(activation_post_process_3);  activation_post_process_3 = None
#     activation_post_process_4 = self.activation_post_process_4(base_layer1_0_conv2);  base_layer1_0_conv2 = None
#     add = activation_post_process_4 + activation_post_process_2;  activation_post_process_4 = activation_post_process_2 = None
#     base_layer1_0_relu_1 = getattr(self.base.layer1, "0").relu(add);  add = None
#     activation_post_process_5 = self.activation_post_process_5(base_layer1_0_relu_1);  base_layer1_0_relu_1 = None
#     base_layer1_1_conv1 = getattr(self.base.layer1, "1").conv1(activation_post_process_5)
#     activation_post_process_6 = self.activation_post_process_6(base_layer1_1_conv1);  base_layer1_1_conv1 = None
#     base_layer1_1_conv2 = getattr(self.base.layer1, "1").conv2(activation_post_process_6);  activation_post_process_6 = None
#     activation_post_process_7 = self.activation_post_process_7(base_layer1_1_conv2);  base_layer1_1_conv2 = None
#     add_1 = activation_post_process_7 + activation_post_process_5;  activation_post_process_7 = activation_post_process_5 = None
#     base_layer1_1_relu_1 = getattr(self.base.layer1, "1").relu(add_1);  add_1 = None
#     activation_post_process_8 = self.activation_post_process_8(base_layer1_1_relu_1);  base_layer1_1_relu_1 = None
#     base_layer2_0_conv1 = getattr(self.base.layer2, "0").conv1(activation_post_process_8)
#     activation_post_process_9 = self.activation_post_process_9(base_layer2_0_conv1);  base_layer2_0_conv1 = None
#     base_layer2_0_conv2 = getattr(self.base.layer2, "0").conv2(activation_post_process_9);  activation_post_process_9 = None
#     activation_post_process_10 = self.activation_post_process_10(base_layer2_0_conv2);  base_layer2_0_conv2 = None
#     base_layer2_0_downsample_0 = getattr(getattr(self.base.layer2, "0").downsample, "0")(activation_post_process_8);  activation_post_process_8 = None
#     activation_post_process_11 = self.activation_post_process_11(base_layer2_0_downsample_0);  base_layer2_0_downsample_0 = None
#     add_2 = activation_post_process_10 + activation_post_process_11;  activation_post_process_10 = activation_post_process_11 = None
#     base_layer2_0_relu_1 = getattr(self.base.layer2, "0").relu(add_2);  add_2 = None
#     activation_post_process_12 = self.activation_post_process_12(base_layer2_0_relu_1);  base_layer2_0_relu_1 = None
#     base_layer2_1_conv1 = getattr(self.base.layer2, "1").conv1(activation_post_process_12)
#     activation_post_process_13 = self.activation_post_process_13(base_layer2_1_conv1);  base_layer2_1_conv1 = None
#     base_layer2_1_conv2 = getattr(self.base.layer2, "1").conv2(activation_post_process_13);  activation_post_process_13 = None
#     activation_post_process_14 = self.activation_post_process_14(base_layer2_1_conv2);  base_layer2_1_conv2 = None
#     add_3 = activation_post_process_14 + activation_post_process_12;  activation_post_process_14 = activation_post_process_12 = None
#     base_layer2_1_relu_1 = getattr(self.base.layer2, "1").relu(add_3);  add_3 = None
#     activation_post_process_15 = self.activation_post_process_15(base_layer2_1_relu_1);  base_layer2_1_relu_1 = None
#     base_layer3_0_conv1 = getattr(self.base.layer3, "0").conv1(activation_post_process_15)
#     activation_post_process_16 = self.activation_post_process_16(base_layer3_0_conv1);  base_layer3_0_conv1 = None
#     base_layer3_0_conv2 = getattr(self.base.layer3, "0").conv2(activation_post_process_16);  activation_post_process_16 = None
#     activation_post_process_17 = self.activation_post_process_17(base_layer3_0_conv2);  base_layer3_0_conv2 = None
#     base_layer3_0_downsample_0 = getattr(getattr(self.base.layer3, "0").downsample, "0")(activation_post_process_15);  activation_post_process_15 = None
#     activation_post_process_18 = self.activation_post_process_18(base_layer3_0_downsample_0);  base_layer3_0_downsample_0 = None
#     add_4 = activation_post_process_17 + activation_post_process_18;  activation_post_process_17 = activation_post_process_18 = None
#     base_layer3_0_relu_1 = getattr(self.base.layer3, "0").relu(add_4);  add_4 = None
#     activation_post_process_19 = self.activation_post_process_19(base_layer3_0_relu_1);  base_layer3_0_relu_1 = None
#     base_layer3_1_conv1 = getattr(self.base.layer3, "1").conv1(activation_post_process_19)
#     activation_post_process_20 = self.activation_post_process_20(base_layer3_1_conv1);  base_layer3_1_conv1 = None
#     base_layer3_1_conv2 = getattr(self.base.layer3, "1").conv2(activation_post_process_20);  activation_post_process_20 = None
#     activation_post_process_21 = self.activation_post_process_21(base_layer3_1_conv2);  base_layer3_1_conv2 = None
#     add_5 = activation_post_process_21 + activation_post_process_19;  activation_post_process_21 = activation_post_process_19 = None
#     base_layer3_1_relu_1 = getattr(self.base.layer3, "1").relu(add_5);  add_5 = None
#     activation_post_process_22 = self.activation_post_process_22(base_layer3_1_relu_1);  base_layer3_1_relu_1 = None
#     base_layer4_0_conv1 = getattr(self.base.layer4, "0").conv1(activation_post_process_22)
#     activation_post_process_23 = self.activation_post_process_23(base_layer4_0_conv1);  base_layer4_0_conv1 = None
#     base_layer4_0_conv2 = getattr(self.base.layer4, "0").conv2(activation_post_process_23);  activation_post_process_23 = None
#     activation_post_process_24 = self.activation_post_process_24(base_layer4_0_conv2);  base_layer4_0_conv2 = None
#     base_layer4_0_downsample_0 = getattr(getattr(self.base.layer4, "0").downsample, "0")(activation_post_process_22);  activation_post_process_22 = None
#     activation_post_process_25 = self.activation_post_process_25(base_layer4_0_downsample_0);  base_layer4_0_downsample_0 = None
#     add_6 = activation_post_process_24 + activation_post_process_25;  activation_post_process_24 = activation_post_process_25 = None
#     base_layer4_0_relu_1 = getattr(self.base.layer4, "0").relu(add_6);  add_6 = None
#     activation_post_process_26 = self.activation_post_process_26(base_layer4_0_relu_1);  base_layer4_0_relu_1 = None
#     base_layer4_1_conv1 = getattr(self.base.layer4, "1").conv1(activation_post_process_26)
#     activation_post_process_27 = self.activation_post_process_27(base_layer4_1_conv1);  base_layer4_1_conv1 = None
#     base_layer4_1_conv2 = getattr(self.base.layer4, "1").conv2(activation_post_process_27);  activation_post_process_27 = None
#     activation_post_process_28 = self.activation_post_process_28(base_layer4_1_conv2);  base_layer4_1_conv2 = None
#     add_7 = activation_post_process_28 + activation_post_process_26;  activation_post_process_28 = activation_post_process_26 = None
#     base_layer4_1_relu_1 = getattr(self.base.layer4, "1").relu(add_7);  add_7 = None
#     activation_post_process_29 = self.activation_post_process_29(base_layer4_1_relu_1);  base_layer4_1_relu_1 = None
#     base_avgpool = self.base.avgpool(activation_post_process_29);  activation_post_process_29 = None
#     activation_post_process_30 = self.activation_post_process_30(base_avgpool);  base_avgpool = None
#     flatten = torch.flatten(activation_post_process_30, 1);  activation_post_process_30 = None
#     activation_post_process_31 = self.activation_post_process_31(flatten);  flatten = None
#     base_fc = self.base.fc(activation_post_process_31);  activation_post_process_31 = None
#     activation_post_process_32 = self.activation_post_process_32(base_fc);  base_fc = None
#     return activation_post_process_32
#
# # To see more debug info, please use `graph_module.print_readable()`

# %% [markdown]
# #### Все что нам осталось сделать это конвертировать нашу модель, проверить качество ее работы и скорость.
#
# После этого шага мы видим что у нас больше нет сверточных функций, вместо них квантованные свертки, а так же у нес больше нет вспомогательных "наблюдателей".

# %%
qmodel_int8 = convert_fx(prepared_model)
print(qmodel_int8)
# Out:
# GraphModule(
#   (base): Module(
#     (conv1): QuantizedConvReLU2d(3, 64, kernel_size=(7, 7), stride=(2, 2), scale=0.03223159909248352, zero_point=0, padding=(3, 3))
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.018650511279702187, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.04987005516886711, zero_point=72, padding=(1, 1))
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.017917748540639877, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), scale=0.06933116167783737, zero_point=78, padding=(1, 1))
#       )
#     )
#     (layer2): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(64, 128, kernel_size=(3, 3), stride=(2, 2), scale=0.0158312376588583, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.04730905592441559, zero_point=62, padding=(1, 1))
#         (downsample): Module(
#           (0): QuantizedConv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), scale=0.04463627561926842, zero_point=73)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.016301527619361877, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), scale=0.043904490768909454, zero_point=78, padding=(1, 1))
#       )
#     )
#     (layer3): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(128, 256, kernel_size=(3, 3), stride=(2, 2), scale=0.018724223598837852, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.044865839183330536, zero_point=49, padding=(1, 1))
#         (downsample): Module(
#           (0): QuantizedConv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), scale=0.02292337641119957, zero_point=57)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.01884453371167183, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), scale=0.057406116276979446, zero_point=86, padding=(1, 1))
#       )
#     )
#     (layer4): Module(
#       (0): Module(
#         (conv1): QuantizedConvReLU2d(256, 512, kernel_size=(3, 3), stride=(2, 2), scale=0.01292051374912262, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.08444864302873611, zero_point=60, padding=(1, 1))
#         (downsample): Module(
#           (0): QuantizedConv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), scale=0.03133179247379303, zero_point=57)
#         )
#       )
#       (1): Module(
#         (conv1): QuantizedConvReLU2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.04696914926171303, zero_point=0, padding=(1, 1))
#         (conv2): QuantizedConv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), scale=0.44242772459983826, zero_point=60, padding=(1, 1))
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): QuantizedLinear(in_features=512, out_features=10, scale=0.9804986119270325, zero_point=115, qscheme=torch.per_tensor_affine)
#   )
# )
#
#
#
# def forward(self, x : torch.Tensor) -> torch.Tensor:
#     base_conv1_input_scale_0 = self.base_conv1_input_scale_0
#     base_conv1_input_zero_point_0 = self.base_conv1_input_zero_point_0
#     quantize_per_tensor = torch.quantize_per_tensor(x, base_conv1_input_scale_0, base_conv1_input_zero_point_0, torch.quint8);  x = base_conv1_input_scale_0 = base_conv1_input_zero_point_0 = None
#     base_conv1 = self.base.conv1(quantize_per_tensor);  quantize_per_tensor = None
#     base_maxpool = self.base.maxpool(base_conv1);  base_conv1 = None
#     base_layer1_0_conv1 = getattr(self.base.layer1, "0").conv1(base_maxpool)
#     base_layer1_0_conv2 = getattr(self.base.layer1, "0").conv2(base_layer1_0_conv1);  base_layer1_0_conv1 = None
#     base_layer1_0_relu_scale_0 = self.base_layer1_0_relu_scale_0
#     base_layer1_0_relu_zero_point_0 = self.base_layer1_0_relu_zero_point_0
#     add_relu = torch.ops.quantized.add_relu(base_layer1_0_conv2, base_maxpool, base_layer1_0_relu_scale_0, base_layer1_0_relu_zero_point_0);  base_layer1_0_conv2 = base_maxpool = base_layer1_0_relu_scale_0 = base_layer1_0_relu_zero_point_0 = None
#     base_layer1_1_conv1 = getattr(self.base.layer1, "1").conv1(add_relu)
#     base_layer1_1_conv2 = getattr(self.base.layer1, "1").conv2(base_layer1_1_conv1);  base_layer1_1_conv1 = None
#     base_layer1_1_relu_scale_0 = self.base_layer1_1_relu_scale_0
#     base_layer1_1_relu_zero_point_0 = self.base_layer1_1_relu_zero_point_0
#     add_relu_1 = torch.ops.quantized.add_relu(base_layer1_1_conv2, add_relu, base_layer1_1_relu_scale_0, base_layer1_1_relu_zero_point_0);  base_layer1_1_conv2 = add_relu = base_layer1_1_relu_scale_0 = base_layer1_1_relu_zero_point_0 = None
#     base_layer2_0_conv1 = getattr(self.base.layer2, "0").conv1(add_relu_1)
#     base_layer2_0_conv2 = getattr(self.base.layer2, "0").conv2(base_layer2_0_conv1);  base_layer2_0_conv1 = None
#     base_layer2_0_downsample_0 = getattr(getattr(self.base.layer2, "0").downsample, "0")(add_relu_1);  add_relu_1 = None
#     base_layer2_0_relu_scale_0 = self.base_layer2_0_relu_scale_0
#     base_layer2_0_relu_zero_point_0 = self.base_layer2_0_relu_zero_point_0
#     add_relu_2 = torch.ops.quantized.add_relu(base_layer2_0_conv2, base_layer2_0_downsample_0, base_layer2_0_relu_scale_0, base_layer2_0_relu_zero_point_0);  base_layer2_0_conv2 = base_layer2_0_downsample_0 = base_layer2_0_relu_scale_0 = base_layer2_0_relu_zero_point_0 = None
#     base_layer2_1_conv1 = getattr(self.base.layer2, "1").conv1(add_relu_2)
#     base_layer2_1_conv2 = getattr(self.base.layer2, "1").conv2(base_layer2_1_conv1);  base_layer2_1_conv1 = None
#     base_layer2_1_relu_scale_0 = self.base_layer2_1_relu_scale_0
#     base_layer2_1_relu_zero_point_0 = self.base_layer2_1_relu_zero_point_0
#     add_relu_3 = torch.ops.quantized.add_relu(base_layer2_1_conv2, add_relu_2, base_layer2_1_relu_scale_0, base_layer2_1_relu_zero_point_0);  base_layer2_1_conv2 = add_relu_2 = base_layer2_1_relu_scale_0 = base_layer2_1_relu_zero_point_0 = None
#     base_layer3_0_conv1 = getattr(self.base.layer3, "0").conv1(add_relu_3)
#     base_layer3_0_conv2 = getattr(self.base.layer3, "0").conv2(base_layer3_0_conv1);  base_layer3_0_conv1 = None
#     base_layer3_0_downsample_0 = getattr(getattr(self.base.layer3, "0").downsample, "0")(add_relu_3);  add_relu_3 = None
#     base_layer3_0_relu_scale_0 = self.base_layer3_0_relu_scale_0
#     base_layer3_0_relu_zero_point_0 = self.base_layer3_0_relu_zero_point_0
#     add_relu_4 = torch.ops.quantized.add_relu(base_layer3_0_conv2, base_layer3_0_downsample_0, base_layer3_0_relu_scale_0, base_layer3_0_relu_zero_point_0);  base_layer3_0_conv2 = base_layer3_0_downsample_0 = base_layer3_0_relu_scale_0 = base_layer3_0_relu_zero_point_0 = None
#     base_layer3_1_conv1 = getattr(self.base.layer3, "1").conv1(add_relu_4)
#     base_layer3_1_conv2 = getattr(self.base.layer3, "1").conv2(base_layer3_1_conv1);  base_layer3_1_conv1 = None
#     base_layer3_1_relu_scale_0 = self.base_layer3_1_relu_scale_0
#     base_layer3_1_relu_zero_point_0 = self.base_layer3_1_relu_zero_point_0
#     add_relu_5 = torch.ops.quantized.add_relu(base_layer3_1_conv2, add_relu_4, base_layer3_1_relu_scale_0, base_layer3_1_relu_zero_point_0);  base_layer3_1_conv2 = add_relu_4 = base_layer3_1_relu_scale_0 = base_layer3_1_relu_zero_point_0 = None
#     base_layer4_0_conv1 = getattr(self.base.layer4, "0").conv1(add_relu_5)
#     base_layer4_0_conv2 = getattr(self.base.layer4, "0").conv2(base_layer4_0_conv1);  base_layer4_0_conv1 = None
#     base_layer4_0_downsample_0 = getattr(getattr(self.base.layer4, "0").downsample, "0")(add_relu_5);  add_relu_5 = None
#     base_layer4_0_relu_scale_0 = self.base_layer4_0_relu_scale_0
#     base_layer4_0_relu_zero_point_0 = self.base_layer4_0_relu_zero_point_0
#     add_relu_6 = torch.ops.quantized.add_relu(base_layer4_0_conv2, base_layer4_0_downsample_0, base_layer4_0_relu_scale_0, base_layer4_0_relu_zero_point_0);  base_layer4_0_conv2 = base_layer4_0_downsample_0 = base_layer4_0_relu_scale_0 = base_layer4_0_relu_zero_point_0 = None
#     base_layer4_1_conv1 = getattr(self.base.layer4, "1").conv1(add_relu_6)
#     base_layer4_1_conv2 = getattr(self.base.layer4, "1").conv2(base_layer4_1_conv1);  base_layer4_1_conv1 = None
#     base_layer4_1_relu_scale_0 = self.base_layer4_1_relu_scale_0
#     base_layer4_1_relu_zero_point_0 = self.base_layer4_1_relu_zero_point_0
#     add_relu_7 = torch.ops.quantized.add_relu(base_layer4_1_conv2, add_relu_6, base_layer4_1_relu_scale_0, base_layer4_1_relu_zero_point_0);  base_layer4_1_conv2 = add_relu_6 = base_layer4_1_relu_scale_0 = base_layer4_1_relu_zero_point_0 = None
#     base_avgpool = self.base.avgpool(add_relu_7);  add_relu_7 = None
#     flatten = torch.flatten(base_avgpool, 1);  base_avgpool = None
#     base_fc = self.base.fc(flatten);  flatten = None
#     dequantize_32 = base_fc.dequantize();  base_fc = None
#     return dequantize_32
#
# # To see more debug info, please use `graph_module.print_readable()`

# %%
test(qmodel_int8, testloader, cuda=False)
# Out:
# Accuracy of the network on the test images: 81.19%
# 81.19

# %% [markdown]
# ### Квантованная модель

# %%
qmodel_int8.eval()
test_time(qmodel_int8)
# Out:
# execution time for FP32 model is: 0.0037 +/- 0.0003

# %% [markdown]
# ### Оригинальная модель

# %%
model.eval()
test_time(model)
# Out:
# execution time for FP32 model is: 0.0086 +/- 0.0018

# %% [markdown]
# ### Попробуем дальше улучшить скорость с помощью torch.compile

# %%
model_compiled = torch.compile(model)

# %%
model_compiled.eval()
test_time(model_compiled)
# Out:
# execution time for FP32 model is: 0.1550 +/- 1.4360

# %%
test_time(model_compiled)
# Out:
# execution time for FP32 model is: 0.0129 +/- 0.0012

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Не будем сдаваться и попробуем сделать это с помощью torch.script

# %%
model_jit_int8 = torch.jit.script(qmodel_int8)
test_time(model_jit_int8)
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# execution time for FP32 model is: 0.0015 +/- 0.0004

# %%
batch = torch.rand(1,3,32,32)
model_jit_trace_int8 = torch.jit.trace(qmodel_int8, batch)
test_time(model_jit_trace_int8)
# Out:
# execution time for FP32 model is: 0.0014 +/- 0.0016

# %%
batch = torch.rand(1,3,32,32)
model_jit_trace= torch.jit.trace(model, batch)
test_time(model_jit_trace)
# Out:
# execution time for FP32 model is: 0.0080 +/- 0.0034

# %%
test_time(model)
# Out:
# execution time for FP32 model is: 0.0081 +/- 0.0019

# %% [markdown]
# ### И так, мы увеличили скорость работы модели на CPU почти в 4 раза!

# %%
torch.jit.save(model_jit_int8, 'scriptmodule.pt')

loaded_model = torch.jit.load('scriptmodule.pt')

test_time(loaded_model)
# Out:
# execution time for FP32 model is: 0.0020 +/- 0.0049
